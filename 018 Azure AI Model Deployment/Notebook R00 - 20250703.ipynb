# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

endpoint = "<Azure_Endpoint>/models"
model_name = "AzureAI_Phi-4"

API_KEY = ''

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(API_KEY),
    api_version="2024-05-01-preview"
)

# %% [markdown]
# # **01 Print Response**

# %%
response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful assistant."),
        UserMessage(content="I am going to Paris, what should I see?"),
    ],
    max_tokens=2048,
    temperature=0.8,
    top_p=0.1,
    presence_penalty=0.0,
    frequency_penalty=0.0,
    model=model_name
)

print(response.choices[0].message.content)
# Out:
# Paris is a city rich in history, culture, and beauty. Here are some must-see attractions and experiences:
#
# 1. **Eiffel Tower**: No visit to Paris is complete without seeing this iconic landmark. You can take an elevator to the top for breathtaking views of the city.
#
# 2. **Louvre Museum**: Home to thousands of works of art, including the Mona Lisa and the Venus de Milo, the Louvre is one of the world's largest and most visited museums.
#
# 3. **Notre-Dame Cathedral**: Although it suffered a fire in 2019, the cathedral remains a significant historical and architectural site. You can explore the exterior and the surrounding area.
#
# 4. **Champs-Élysées and Arc de Triomphe**: Stroll down this famous avenue, ending at the Arc de Triomphe, where you can climb to the top for panoramic views.
#
# 5. **Montmartre and Sacré-Cœur**: Visit this historic and artistic neighborhood, known for its bohemian past and the stunning Basilica of the Sacré-Cœur.
#
# 6. **Musée d'Orsay**: Located in a former railway station, this museum houses an extensive collection of Impressionist and Post-Impressionist masterpieces.
#
# 7. **Seine River Cruise**: Take a boat tour to see many of Paris's landmarks from the water, including the Eiffel Tower, Notre-Dame, and the Louvre.
#
# 8. **Palace of Versailles**: A short trip from Paris, this opulent palace and its gardens are a UNESCO World Heritage site and a testament to the grandeur of French royalty.
#
# 9. **Latin Quarter**: Explore this vibrant area known for its student life, lively atmosphere, and historic sites like the Panthéon.
#
# 10. **Sainte-Chapelle**: Known for its stunning stained glass windows, this Gothic chapel is a hidden gem in the heart of Paris.
#
# 11. **Le Marais**: Wander through this historic district, known for its trendy boutiques, galleries, and charming architecture.
#
# 12. **Père Lachaise Cemetery**: Visit the final resting place of famous figures like Oscar Wilde, Jim Morrison, and Edith Piaf.
#
# 13. **Café Culture**: Experience Parisian life by sitting in a café, enjoying a croissant, and people-watching.
#
# 14. **Shopping**: Explore the boutiques along the Rue du Faubourg Saint-Honoré or the Galeries Lafayette for luxury shopping.
#
# 15. **Local Markets**: Visit markets like Marché des Enfants Rouges for fresh produce, cheeses, and local delicacies.
#
# These are just a few highlights, and Paris has much more to offer depending on your interests. Enjoy your trip!

# %% [markdown]
# # **02 Stream Response**

# %%
response = client.complete(
    stream=True,
    messages=[
        SystemMessage(content="You are a helpful assistant."),
        UserMessage(content="I am going to Paris, what should I see?")
    ],
    max_tokens=2048,
    temperature=0.8,
    top_p=0.1,
    presence_penalty=0.0,
    frequency_penalty=0.0,
    model=model_name
)

for update in response:
    if update.choices:
        print(update.choices[0].delta.content or "", end="")
# Out:
# Paris is a city rich in history, culture, and beauty. Here are some must-see attractions and experiences:
#
# 1. **Eiffel Tower**: No visit to Paris is complete without seeing this iconic landmark. Consider going up for a breathtaking view of the city.
#
# 2. **Louvre Museum**: Home to thousands of works of art, including the Mona Lisa and the Venus de Milo, the Louvre is one of the world's largest and most visited museums.
#
# 3. **Notre-Dame Cathedral**: Although it suffered a fire in 2019, the cathedral remains a significant historical and architectural site. Check for updates on restoration progress and visiting options.
#
# 4. **Champs-Élysées and Arc de Triomphe**: Stroll down this famous avenue and visit the Arc de Triomphe for panoramic views of Paris.
#
# 5. **Montmartre and Sacré-Cœur**: Explore the artistic neighborhood of Montmartre and visit the Basilica of the Sacré-Cœur for stunning views over Paris.
#
# 6. **Musée d'Orsay**: Located in a former railway station, this museum houses an extensive collection of Impressionist and Post-Impressionist masterpieces.
#
# 7. **Palace of Versailles**: A short train ride from Paris, this opulent palace and its gardens are a testament to the grandeur of French royalty.
#
# 8. **Seine River Cruise**: Enjoy a relaxing boat tour along the Seine to see many of Paris's landmarks from the water.
#
# 9. **Latin Quarter**: Known for its vibrant atmosphere, this area is perfect for exploring bookshops, cafes, and the historic Panthéon.
#
# 10. **Sainte-Chapelle**: Marvel at the stunning stained glass windows in this Gothic chapel, a true gem of medieval architecture.
#
# 11. **Le Marais**: Wander through this historic district, known for its charming streets, boutiques, and vibrant nightlife.
#
# 12. **Père Lachaise Cemetery**: Visit the final resting place of famous figures like Oscar Wilde and Jim Morrison.
#
# 13. **Catacombs of Paris**: Explore the underground ossuaries that hold the remains of millions of Parisians.
#
# 14. **Picasso Museum**: Discover an extensive collection of Pablo Picasso's works in this beautiful mansion.
#
# 15. **Local Cuisine**: Don’t miss trying classic French dishes like croissants, escargot, and crème brûlée, and enjoy a café au lait at a sidewalk café.
#
# These are just a few highlights, and Paris has much more to offer. Enjoy your trip!
