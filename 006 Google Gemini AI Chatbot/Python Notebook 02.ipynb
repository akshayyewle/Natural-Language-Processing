# %% [markdown]
# # **Setup**
#
# * https://medium.com/random-noise/using-gemini-googles-largest-and-most-capable-ai-model-with-python-ecc6d5fe2a16

# %%
import pandas as pd 
from IPython.display import clear_output
import os

# %%
# !python -m pip install google-generativeai
clear_output()

import google.generativeai as genai

# %% [markdown]
# # **API Setup**

# %%
GOOGLE_API_KEY = os.getenv('Google_AI_Studio_API_Key')
genai.configure(api_key=GOOGLE_API_KEY)

# Get List Of AI Models
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# # **Query 01**

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

response = model.generate_content("What is democracy?")

print(response)
print('\n')
print(response.text)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=glm.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...
