# %% [markdown]
# # **Setup**

# %%
import re

# %% [markdown]
# # **Example 01**

# %%
text = """
        I ordered a vacuum cleaner on Jan 6, 2025, after seeing the expected delivery date as Jan 10, 2025. 
        However, even after waiting for 1 full month today on 09/02/2025 I didn't get the item. 
        If I didn't get my parcel by 2/20/25, I will take the issue with higher authority.
        """

text
# Out:
# "\n        I ordered a vacuum cleaner on Jan 6, 2025, after seeing the expected delivery date as Jan 10, 2025. \n        However, even after waiting for 1 full month today on 09/02/2025 I didn't get the item. \n        If I didn't get my parcel by 2/20/25, I will take the issue with higher authority.\n        "

# %% [markdown]
# # **References**
#
# - https://towardsdatascience.com/3-powerful-examples-of-the-python-re-library-e8d0bea8cd28
